# %%
print("Hello, World!");
# Out:
# Hello, World!

# %%
import sys
print(sys.version)
# Out:
# 3.11.1 (v3.11.1:a7a450f84a, Dec  6 2022, 15:24:06) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
# !python3 --version
# Out:
# Python 3.11.1

# %%
# !pip show panadas
# Out:
# WARNING: Package(s) not found: panadas

# %%
# !pip install \
pandas numpy scipy \
matplotlib seaborn plotly \
openpyxl xlrd xlsxwriter \
python-docx docx2txt \
PyPDF2 pdfplumber \
scikit-learn statsmodels \
jsonschema \
requests beautifulsoup4 \
jupyter ipykernel tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 4.8 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 4.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 3.4 MB/s eta 0:00:00 0:00:01
# ...
#   Attempting uninstall: narwhals
#     Found existing installation: narwhals 1.9.0
# ...

# %%
# !pip freeze > requirements.txt

# %%
# !pip install openpyxl

# %%
# !python3 --version
# Out:
# Python 3.11.1

# %%
# !pip show openpyxl
# Out:
# Name: openpyxl
# Version: 3.1.2
# Summary: A Python library to read/write Excel 2010 xlsx/xlsm files
# Home-page: https://openpyxl.readthedocs.io
# Author: See AUTHORS
# Author-email: charlie.clark@clark-consulting.eu
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages
# Requires: et-xmlfile
# Required-by:

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
import sys
print(sys)
# Out:
# <module 'sys' (built-in)>

# %%
# !pip3 install pandas

# %%
import pandas as pd

handloom_df=pd.read_excel("data/HandloomStock.xlsx")
item_df= pd.read_excel("data/Item_list.xlsx")

# %%
print(handloom_df.head())
# Out:
#   Location       Vijayawada            Unnamed: 2         Unnamed: 3
# 0      NaN              NaN                   NaN                NaN
# 1      NaN             Data                   NaN                NaN
# 2     Item  Sum of Quantity  Average of Unit Cost  Sum of Total Cost
# 3     Flag               76            779.710145       37008.695652
# 4   Shirts               34             920.92875         31274.5125

# %%
print(handloom_df.to_string())
# Out:
#        Location       Vijayawada            Unnamed: 2         Unnamed: 3
# 0           NaN              NaN                   NaN                NaN
# 1           NaN             Data                   NaN                NaN
# 2          Item  Sum of Quantity  Average of Unit Cost  Sum of Total Cost
# 3          Flag               76            779.710145       37008.695652
# 4        Shirts               34             920.92875         31274.5125
# 5  Total Result              110            888.339841       68283.208152

# %%
print(handloom_df.columns)
print(item_df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(handloom_df.columns)
#       2 print(item_df.columns)
#
# NameError: name 'handloom_df' is not defined

# %%
print(item_df.head())
# Out:
#                                  Company Name      Item Code  \
# 0  Yalamanchili Manufacturing Private Limited      munch0001
# 1  Yalamanchili Manufacturing Private Limited           P001
# 2  Yalamanchili Manufacturing Private Limited      scale0123
# 3  Yalamanchili Manufacturing Private Limited  CleanSoln0001
# 4  Yalamanchili Manufacturing Private Limited  CleanSoln0001
#
#                           Item Name       Barcode  Amount    Status  \
# 0    Munch | Chocolate | 17.4 Grams  8.901058e+12    10.0    Active
# 1              Apsara | Pencil | HB           NaN     5.0    Active
# 2          Skoodle | Scale | 15 cms  8.904384e+12     7.0    Active
# 3                   Surface Cleaner           NaN   115.0  Deactive
# 4  Colin | Surface Cleaner | 500 mL  8.914600e+04   115.0    Active
#
#   Product ID Branch Name Warehouse Name  HSN Code  CGST  SGST   IGST  \
# 0  ITEM00357  Vijayawada  AAO_Jaibharat      1806  2.5%  2.5%   5.0%
# ...

# %%
print(item_df.columns)
# Out:
# Index(['Company Name', 'Item Code', 'Item Name', 'Barcode', 'Amount', 'Status',
#        'Product ID', 'Branch Name', 'Warehouse Name', 'HSN Code', 'CGST',
#        'SGST', 'IGST', 'Reorder Level', 'Category', 'Sub Category',
#        'Base Value'],
#       dtype='object')

# %%
print(item_df.iloc[0])
# Out:
# Company Name      Yalamanchili Manufacturing Private Limited
# Item Code                                          munch0001
# Item Name                     Munch | Chocolate | 17.4 Grams
# Barcode                                      8901058022179.0
# Amount                                                  10.0
# Status                                                Active
# Product ID                                         ITEM00357
# Branch Name                                       Vijayawada
# Warehouse Name                                 AAO_Jaibharat
# HSN Code                                                1806
# CGST                                                    2.5%
# SGST                                                    2.5%
# IGST                                                    5.0%
# Reorder Level                                           25.0
# Category                                     Snacks & Drinks
# ...

# %%
import pandas as pd
xls = pd.ExcelFile("data/HandloomStock.xlsx")
print(xls.sheet_names)
# Out:
# ['Summary', 'Consolidated', 'Yarn', 'Cloth', 'Flags', 'Shirts', 'Nagpur Stock', 'T Shirts', 'Saree']

# %%
cloth_df = pd.read_excel("data/HandloomStock.xlsx", sheet_name="Cloth")
print(cloth_df.head())
# Out:
#    SNO Cloth Type Colour Code  Total(Mtrs) Remarks
# 0    1     Checks     C-102-C        10.50     NaN
# 1    2     Checks     C-118-C        51.67     NaN
# 2    3     Checks     C-123-C         2.70     NaN
# 3    4     Checks     C-125-C        28.30     NaN
# 4    5     Checks     C-126-C        24.10     NaN

# %%
print(cloth_df.iloc[0])
# Out:
# SNO                  1
# Cloth Type      Checks
# Colour Code    C-102-C
# Total(Mtrs)       10.5
# Remarks            NaN
# Name: 0, dtype: object
